# %%
pip install Matplotlib
# Out:
# Collecting Matplotlib
#   Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from Matplotlib)
#   Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from Matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from Matplotlib)
#   Downloading fonttools-4.58.0-cp313-cp313-win_amd64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from Matplotlib)
#   Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from Matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from Matplotlib) (24.2)
# Collecting pillow>=8 (from Matplotlib)
#   Downloading pillow-11.2.1-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from Matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from Matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from python-dateutil>=2.7->Matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 10.0 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 15.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 17.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 12.3 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl (223 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.0-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------------------------- -- 2.1/2.2 MB 21.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 9.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Downloading pillow-11.2.1-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 13.6 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, Matplotlib
# Successfully installed Matplotlib-3.10.3 contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.0 kiwisolver-1.4.8 pillow-11.2.1 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\dell\desktop\numpy\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\desktop\numpy\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import DataFrame

# %%
data = {'names':['steve','john', 'richard' ,'sarah','randy','micheal','julie'],
        'age': [20,22,20,21,24,23,22],
        'gender':['male','male','male','female','male','male','female'],
        'rank':[2,1,4,5,3,7,6]}

df=DataFrame(data)
df
# Out:
#      names  age  gender  rank
# 0    steve   20    male     2
# 1     john   22    male     1
# 2  richard   20    male     4
# 3    sarah   21  female     5
# 4    randy   24    male     3
# 5  micheal   23    male     7
# 6    julie   22  female     6

# %% [markdown]
# matplotlib barchart

# %%
plt.bar(df['names'],df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %% [markdown]
# seaborn barchart

# %%
plot = sns.barplot(data=df, x= 'names', y = 'age')
plot.set_title('comparing ages')
plt.show()

# %% [markdown]
# line plot matplotlib

# %%
plt.plot(df['names'],df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title('Comparing Ages')
plt.show()

# %% [markdown]
# line plot seaborn

# %%
plot = sns.lineplot(data=df, x= 'names', y = 'age')
plt.show()

# %% [markdown]
# pie chart Matplotlib

# %%
plt.pie(df['age'], labels = df['names'])
plt.title('Age Comparison')
plt.show()

# %% [markdown]
# pie chat seaborn

# %%
colors = sns.color_palette('pastel')[0:5]
plt.pie(df['age'], labels = df['names'], colors= colors)
plt.show()
